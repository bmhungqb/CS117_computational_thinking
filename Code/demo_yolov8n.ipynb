# %%
# !nvidia-smi
# Out:
# Thu Jan  4 13:18:52 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.161.03   Driver Version: 470.161.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/bmhungqb/CS117_computational_thinking.git
# Out:
# Cloning into 'CS117_computational_thinking'...
# remote: Enumerating objects: 121, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 121 (delta 6), reused 28 (delta 4), pack-reused 89
# Receiving objects: 100% (121/121), 107.61 MiB | 18.52 MiB/s, done.
# Resolving deltas: 100% (29/29), done.

# %%
# !pip install -r /kaggle/working/CS117_computational_thinking/requirements.txt
# Out:
# ...
#   Obtaining dependency information for matplotlib==3.8.2 from https://files.pythonhosted.org/packages/19/e5/a4ea514515f270224435c69359abb7a3d152ed31b9ee3ba5e63017461945/matplotlib-3.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...
#   Obtaining dependency information for ultralytics from https://files.pythonhosted.org/packages/17/72/3f6d4c9a72ca378168183124b2d4e595cb7f4ec2d0fa221db88b9f7bd9b9/ultralytics-8.0.234-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.3/388.3 kB 33.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Obtaining dependency information for imageio_ffmpeg>=0.2.0 from https://files.pythonhosted.org/packages/1a/98/3df1d8dd8f2c121b6c588b1e0d604f36592d56df9c41fb155ed546c6a5ed/imageio_ffmpeg-0.4.9-py3-none-manylinux2010_x86_64.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 81.8 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# %cd /kaggle/working/CS117_computational_thinking
# Out:
# /kaggle/working/CS117_computational_thinking

# %%
# !mkdir output_video

# %%
# %%writefile /kaggle/working/CS117_computational_thinking/Code/reference.py
from PIL import Image
import numpy as np
from moviepy.editor import VideoFileClip, ImageSequenceClip
from ultralytics import YOLO
import cv2
# Load YOLO model
model = YOLO(r"/kaggle/input/cs117-models/best_yolov8n.pt")

# Define path to video file
source = r"/kaggle/input/data-demo-cs117/demo/demo/video_demo.mp4"

# Run inference on the source
results = model(source, stream=True, save=True, device=0, conf=0.25)

# Initialize video clip
video_clip = VideoFileClip(source)
fps = video_clip.fps
size = video_clip.size

# Create a list to store processed frames
processed_frames = []

# Process each frame and save the video
for frame, r in zip(video_clip.iter_frames(fps=fps, dtype='uint8'), results):
    # Plot bounding boxes on the frame with customization
    im_array = r.plot(line_width=2, font_size=4)
    im = Image.fromarray(im_array[..., ::-1])  # Convert to RGB PIL image
    # frame = process_image(frame)
    frame_with_overlay = Image.blend(Image.fromarray(frame), im, alpha=0.5)

    np_frame = np.array(frame_with_overlay)

    # Append the processed frame to the list
    processed_frames.append(np_frame)

# Create an ImageSequenceClip from the processed frames
processed_clip = ImageSequenceClip(processed_frames, fps=fps)

# Save the processed video
processed_clip.write_videofile("output_video/video_demo.mp4", codec="libx264", audio_codec="aac")
# Out:
# Overwriting /kaggle/working/CS117_computational_thinking/Code/reference.py

# %%
# !python /kaggle/working/CS117_computational_thinking/Code/reference.py
# Out:
# video 1/1 (1/608) /kaggle/input/data-demo-cs117/demo/demo/video_demo.mp4: 384x640 1 gbottle, 56.8ms
# video 1/1 (2/608) /kaggle/input/data-demo-cs117/demo/demo/video_demo.mp4: 384x640 1 gbottle, 7.7ms
# video 1/1 (3/608) /kaggle/input/data-demo-cs117/demo/demo/video_demo.mp4: 384x640 2 pbottles, 9.9ms
# video 1/1 (4/608) /kaggle/input/data-demo-cs117/demo/demo/video_demo.mp4: 384x640 (no detections), 7.4ms
# video 1/1 (5/608) /kaggle/input/data-demo-cs117/demo/demo/video_demo.mp4: 384x640 (no detections), 9.8ms
# video 1/1 (6/608) /kaggle/input/data-demo-cs117/demo/demo/video_demo.mp4: 384x640 1 pbag, 1 pbottle, 9.4ms
# video 1/1 (7/608) /kaggle/input/data-demo-cs117/demo/demo/video_demo.mp4: 384x640 1 pbag, 1 pbottle, 9.3ms
# video 1/1 (8/608) /kaggle/input/data-demo-cs117/demo/demo/video_demo.mp4: 384x640 1 pbag, 1 pbottle, 9.3ms
# video 1/1 (9/608) /kaggle/input/data-demo-cs117/demo/demo/video_demo.mp4: 384x640 1 pbag, 2 pbottles, 9.3ms
# ...

# %%
from ultralytics import YOLO
model = YOLO(r"/kaggle/input/cs117-models/best_yolov8n.pt")
# Run inference on 'bus.jpg' with arguments
model.predict('/kaggle/input/data-demo-cs117/demo/demo/img1.jpg', save=True, conf=0.25,show=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /kaggle/input/data-demo-cs117/demo/demo/img1.jpg: 448x640 2 pbags, 51.6ms
# Speed: 4.3ms preprocess, 51.6ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict3
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Mask', 1: 'can', 2: 'cellphone', 3: 'electronics', 4: 'gbottle', 5: 'glove', 6: 'metal', 7: 'misc', 8: 'net', 9: 'pbag', 10: 'pbottle', 11: 'plastic', 12: 'rod', 13: 'sunglasses', 14: 'tire'}
#  orig_img: array([[[181, 182,  86],
#          [180, 181,  85],
#          [179, 180,  84],
#          ...,
#          [161, 158,  67],
#          [163, 162,  71],
#          [166, 165,  74]],
#
#         [[183, 184,  88],
#          [182, 183,  87],
#          [181, 182,  86],
#          ...,
#          [166, 163,  72],
# ...

# %%
model = YOLO(r"/kaggle/input/cs117-models/best_yolov8n.pt")
model.predict('/kaggle/input/data-demo-cs117/demo/demo/img2.jpg', save=True, conf=0.25,show=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /kaggle/input/data-demo-cs117/demo/demo/img2.jpg: 416x640 1 pbag, 1 pbottle, 9.8ms
# Speed: 2.4ms preprocess, 9.8ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs/detect/predict4
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Mask', 1: 'can', 2: 'cellphone', 3: 'electronics', 4: 'gbottle', 5: 'glove', 6: 'metal', 7: 'misc', 8: 'net', 9: 'pbag', 10: 'pbottle', 11: 'plastic', 12: 'rod', 13: 'sunglasses', 14: 'tire'}
#  orig_img: array([[[ 86,  78,  48],
#          [ 86,  78,  48],
#          [ 85,  77,  47],
#          ...,
#          [193, 182, 152],
#          [193, 182, 152],
#          [193, 182, 152]],
#
#         [[ 86,  78,  48],
#          [ 86,  78,  48],
#          [ 86,  78,  48],
#          ...,
#          [192, 181, 151],
# ...

# %%
model = YOLO(r"/kaggle/input/cs117-models/best_yolov8n.pt")
model.predict('/kaggle/input/data-demo-cs117/demo/demo/img3.jpg', save=True, conf=0.25,show=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /kaggle/input/data-demo-cs117/demo/demo/img3.jpg: 448x640 1 pbag, 6.0ms
# Speed: 1.8ms preprocess, 6.0ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict5
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Mask', 1: 'can', 2: 'cellphone', 3: 'electronics', 4: 'gbottle', 5: 'glove', 6: 'metal', 7: 'misc', 8: 'net', 9: 'pbag', 10: 'pbottle', 11: 'plastic', 12: 'rod', 13: 'sunglasses', 14: 'tire'}
#  orig_img: array([[[27, 10,  1],
#          [26,  9,  0],
#          [26,  9,  0],
#          ...,
#          [37,  0,  2],
#          [38,  1,  3],
#          [39,  2,  4]],
#
#         [[27, 10,  1],
#          [26,  9,  0],
#          [26,  9,  0],
#          ...,
#          [37,  0,  2],
#          [37,  0,  2],
# ...

# %%
model = YOLO(r"/kaggle/input/cs117-models/best_yolov8n.pt")
model.predict('/kaggle/input/data-demo-cs117/demo/demo/img4.jpg', save=True, conf=0.25,show=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /kaggle/input/data-demo-cs117/demo/demo/img4.jpg: 384x640 1 pbag, 53.4ms
# Speed: 1.5ms preprocess, 53.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict6
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Mask', 1: 'can', 2: 'cellphone', 3: 'electronics', 4: 'gbottle', 5: 'glove', 6: 'metal', 7: 'misc', 8: 'net', 9: 'pbag', 10: 'pbottle', 11: 'plastic', 12: 'rod', 13: 'sunglasses', 14: 'tire'}
#  orig_img: array([[[153, 153,  75],
#          [162, 157,  78],
#          [177, 159,  82],
#          ...,
#          [ 83,  95,  19],
#          [ 84,  96,  20],
#          [ 84,  96,  20]],
#
#         [[179, 168,  84],
#          [183, 168,  82],
#          [192, 166,  82],
#          ...,
#          [ 83,  95,  19],
# ...

# %%
model = YOLO(r"/kaggle/input/cs117-models/best_yolov8n.pt")
model.predict('/kaggle/input/data-demo-cs117/demo/demo/img5.jpg', save=True, conf=0.25,show=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /kaggle/input/data-demo-cs117/demo/demo/img5.jpg: 480x640 2 pbags, 6.2ms
# Speed: 1.9ms preprocess, 6.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict7
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Mask', 1: 'can', 2: 'cellphone', 3: 'electronics', 4: 'gbottle', 5: 'glove', 6: 'metal', 7: 'misc', 8: 'net', 9: 'pbag', 10: 'pbottle', 11: 'plastic', 12: 'rod', 13: 'sunglasses', 14: 'tire'}
#  orig_img: array([[[109,  79,   0],
#          [103,  76,   0],
#          [ 94,  75,   2],
#          ...,
#          [122, 116,  57],
#          [121, 115,  56],
#          [118, 113,  52]],
#
#         [[100,  74,   0],
#          [ 98,  78,   1],
#          [ 94,  79,   7],
#          ...,
#          [120, 114,  55],
# ...

# %%
model = YOLO(r"/kaggle/input/cs117-models/best_yolov8n.pt")
model.predict('/kaggle/input/data-demo-cs117/demo/demo/img6.jpg', save=True, conf=0.25,show=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/1 /kaggle/input/data-demo-cs117/demo/demo/img6.jpg: 352x640 2 pbags, 2 pbottles, 59.1ms
# Speed: 1.5ms preprocess, 59.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to runs/detect/predict8
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Mask', 1: 'can', 2: 'cellphone', 3: 'electronics', 4: 'gbottle', 5: 'glove', 6: 'metal', 7: 'misc', 8: 'net', 9: 'pbag', 10: 'pbottle', 11: 'plastic', 12: 'rod', 13: 'sunglasses', 14: 'tire'}
#  orig_img: array([[[ 20,  15,  12],
#          [ 20,  15,  12],
#          [ 19,  14,  11],
#          ...,
#          [156, 112,  48],
#          [155, 113,  48],
#          [156, 114,  49]],
#
#         [[ 20,  15,  12],
#          [ 20,  15,  12],
#          [ 19,  14,  11],
#          ...,
#          [156, 112,  48],
# ...
